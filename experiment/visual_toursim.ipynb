# %%
import matplotlib.pyplot as plt
from load_data import load_tourismV4

# %%
import numpy as np
import pandas as pd

# %%
toursim_train, tourism_test = load_tourismV4()

# %% [markdown]
# # 数据可视化

# %%
time_index = pd.date_range(start='1998-01-01', freq='1M', periods=228)
top = toursim_train.aggregate_ts(0)
plt.figure(figsize=(20, 8))
plt.subplot(121)
plt.plot(time_index, top)
plt.title('Level 0')
plt.subplot(122)
plt.plot(time_index, toursim_train.aggregate_ts(1))
plt.title('Level 1')
plt.show()

# %%
t = pd.read_csv("data/TourismData_v4.csv")['DAC']

# %%
plt.plot(time_index, t.values[:228])
plt.show()

# %%
a = pd.Series(t.values[:228], index=time_index)

# %%
(a['2001-12'].values + a['2003-12'].values)/2
# Out:
# array([8.4567957])

# %%
a['2002-12-31'] = 8.4567957

# %%
a.plot()
# Out:
# <AxesSubplot:>
